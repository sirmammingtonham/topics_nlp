# %% [markdown]
# <a href="https://colab.research.google.com/github/sirmammingtonham/topics_nlp/blob/main/seq2seq_reverse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers evaluate datasets sacrebleu accelerate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 58.1 MB/s eta 0:00:00
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 KB 5.1 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.8.0-py3-none-any.whl (452 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.9/452.9 KB 18.1 MB/s eta 0:00:00
# Collecting sacrebleu
#   Downloading sacrebleu-2.3.1-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 KB 8.0 MB/s eta 0:00:00
# Collecting accelerate
#   Downloading accelerate-0.15.0-py3-none-any.whl (191 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.5/191.5 KB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.25.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 36.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: dill in /usr/local/lib/python3.8/dist-packages (from evaluate) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from evaluate) (1.3.5)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 12.6 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py38-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 14.6 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.8/dist-packages (from evaluate) (2022.11.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets) (3.8.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from sacrebleu) (4.9.2)
# Collecting portalocker
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.8/dist-packages (from sacrebleu) (0.8.10)
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from accelerate) (5.4.8)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from accelerate) (1.13.1+cu116)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (22.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (4.0.0)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 20.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->evaluate) (2022.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->evaluate) (1.15.0)
# Installing collected packages: tokenizers, xxhash, urllib3, portalocker, multiprocess, colorama, sacrebleu, accelerate, responses, huggingface-hub, transformers, datasets, evaluate
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed accelerate-0.15.0 colorama-0.4.6 datasets-2.8.0 evaluate-0.4.0 huggingface-hub-0.11.1 multiprocess-0.70.14 portalocker-2.7.0 responses-0.18.0 sacrebleu-2.3.1 tokenizers-0.13.2 transformers-4.25.1 urllib3-1.26.14 xxhash-3.2.0

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, Seq2SeqTrainer, Seq2SeqTrainingArguments, DataCollatorForSeq2Seq
import torch
import evaluate
from datasets import load_dataset
import numpy as np

# %%
model = AutoModelForSeq2SeqLM.from_pretrained("t5-small")
tokenizer = AutoTokenizer.from_pretrained("t5-small")
# Out:
# Downloading:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/242M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# /usr/local/lib/python3.8/dist-packages/transformers/models/t5/tokenization_t5_fast.py:155: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-small automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(

# %%
raw_ds = load_dataset("ag_news")#, split='train[:5%]')
# Out:
# Downloading builder script:   0%|          | 0.00/4.06k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/2.65k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/7.94k [00:00<?, ?B/s]
# Downloading and preparing dataset ag_news/default to /root/.cache/huggingface/datasets/ag_news/default/0.0.0/bc2bcb40336ace1a0374767fc29bb0296cdaf8a6da7298436239c54d79180548...
# Downloading data:   0%|          | 0.00/11.0M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/751k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/120000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/7600 [00:00<?, ? examples/s]
# Dataset ag_news downloaded and prepared to /root/.cache/huggingface/datasets/ag_news/default/0.0.0/bc2bcb40336ace1a0374767fc29bb0296cdaf8a6da7298436239c54d79180548. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
def preprocess(example):
    text = example["text"]
    reverse_text = [" ".join((x.split()[::-1])) for x in text]
    output = tokenizer(example["text"], max_length=256, truncation=True)
    labels = tokenizer(text_target=reverse_text, max_length=256, truncation=True)
    output["labels"] = labels["input_ids"]
    return output

# %%
tokenized_ds = raw_ds.map(preprocess, batched=True, remove_columns=raw_ds['train'].column_names)
tokenized_ds.set_format("torch")
# tokenized_ds = tokenized_ds.train_test_split(test_size=0.2)
train_ds = tokenized_ds["train"]
valid_test = tokenized_ds["test"].train_test_split(test_size=0.5)
valid_ds = valid_test["train"]
test_ds = valid_test["test"]
# Out:
#   0%|          | 0/120 [00:00<?, ?ba/s]
#   0%|          | 0/8 [00:00<?, ?ba/s]

# %%
metric = evaluate.load("sacrebleu")

def postprocess_text(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [[label.strip()] for label in labels]

    return preds, labels

def compute_metrics(eval_preds):
    preds, labels = eval_preds
    if isinstance(preds, tuple):
        preds = preds[0]
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Some simple post-processing
    decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)

    result = metric.compute(predictions=decoded_preds, references=decoded_labels)
    result = {"bleu": result["score"]}

    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in preds]
    result["gen_len"] = np.mean(prediction_lens)
    result = {k: round(v, 4) for k, v in result.items()}
    return result
# Out:
# Downloading builder script:   0%|          | 0.00/8.15k [00:00<?, ?B/s]

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

# %%
trainer = Seq2SeqTrainer(
        model=model,
        args=Seq2SeqTrainingArguments(
            output_dir="/content/output",
            evaluation_strategy = "epoch",
            save_total_limit=2,
            learning_rate=2e-5,
            per_device_train_batch_size=16, 
            per_device_eval_batch_size=16, 
            predict_with_generate=True, 
            fp16=True,
        ),
        train_dataset=train_ds,
        eval_dataset=valid_ds,
        tokenizer=tokenizer,
        data_collator=data_collator,
        compute_metrics=compute_metrics,
    )
# Out:
# Using cuda_amp half precision backend

# %%
train_result = trainer.train()
trainer.save_model(output_dir='out')

metrics = train_result.metrics
trainer.log_metrics("train", metrics)
trainer.save_metrics("train", metrics)
trainer.save_state()
# Out:
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 120000
#   Num Epochs = 3
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 22500
#   Number of trainable parameters = 60506624
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='22500' max='22500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [22500/22500 57:32, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.072400</td>
#       <td>0.008684</td>
#       <td>16.086600</td>
#       <td>18.998400</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.039500</td>
#       <td>0.004678</td>
#       <td>16.094900</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.029300</td>
#       <td>0.004041</td>
#       <td>16.095400</td>
#       <td>19.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to /content/output/checkpoint-500
# Configuration saved in /content/output/checkpoint-500/config.json
# Model weights saved in /content/output/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-500/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-1000
# Configuration saved in /content/output/checkpoint-1000/config.json
# Model weights saved in /content/output/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-1000/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-1500
# Configuration saved in /content/output/checkpoint-1500/config.json
# Model weights saved in /content/output/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-1500/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-2000
# Configuration saved in /content/output/checkpoint-2000/config.json
# Model weights saved in /content/output/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-2000/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-2500
# Configuration saved in /content/output/checkpoint-2500/config.json
# Model weights saved in /content/output/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-2500/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-3000
# Configuration saved in /content/output/checkpoint-3000/config.json
# Model weights saved in /content/output/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-3000/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-3500
# Configuration saved in /content/output/checkpoint-3500/config.json
# Model weights saved in /content/output/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-3500/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-4000
# Configuration saved in /content/output/checkpoint-4000/config.json
# Model weights saved in /content/output/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-4000/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-4500
# Configuration saved in /content/output/checkpoint-4500/config.json
# Model weights saved in /content/output/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-4500/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-5000
# Configuration saved in /content/output/checkpoint-5000/config.json
# Model weights saved in /content/output/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-5000/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-5500
# Configuration saved in /content/output/checkpoint-5500/config.json
# Model weights saved in /content/output/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-5500/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-6000
# Configuration saved in /content/output/checkpoint-6000/config.json
# Model weights saved in /content/output/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-6000/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-6500
# Configuration saved in /content/output/checkpoint-6500/config.json
# Model weights saved in /content/output/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-6500/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-7000
# Configuration saved in /content/output/checkpoint-7000/config.json
# Model weights saved in /content/output/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-7000/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-7500
# Configuration saved in /content/output/checkpoint-7500/config.json
# Model weights saved in /content/output/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-7500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 3800
#   Batch size = 16
# Saving model checkpoint to /content/output/checkpoint-8000
# Configuration saved in /content/output/checkpoint-8000/config.json
# Model weights saved in /content/output/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-8000/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-8500
# Configuration saved in /content/output/checkpoint-8500/config.json
# Model weights saved in /content/output/checkpoint-8500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-8500/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-9000
# Configuration saved in /content/output/checkpoint-9000/config.json
# Model weights saved in /content/output/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-9000/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-9500
# Configuration saved in /content/output/checkpoint-9500/config.json
# Model weights saved in /content/output/checkpoint-9500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-9500/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-10000
# Configuration saved in /content/output/checkpoint-10000/config.json
# Model weights saved in /content/output/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-10000/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-10500
# Configuration saved in /content/output/checkpoint-10500/config.json
# Model weights saved in /content/output/checkpoint-10500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-10500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-10500/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-11000
# Configuration saved in /content/output/checkpoint-11000/config.json
# Model weights saved in /content/output/checkpoint-11000/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-11000/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-11000/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-11500
# Configuration saved in /content/output/checkpoint-11500/config.json
# Model weights saved in /content/output/checkpoint-11500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-11500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-11500/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-12000
# Configuration saved in /content/output/checkpoint-12000/config.json
# Model weights saved in /content/output/checkpoint-12000/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-12000/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-12000/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-12500
# Configuration saved in /content/output/checkpoint-12500/config.json
# Model weights saved in /content/output/checkpoint-12500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-12500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-12500/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-13000
# Configuration saved in /content/output/checkpoint-13000/config.json
# Model weights saved in /content/output/checkpoint-13000/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-13000/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-13000/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-13500
# Configuration saved in /content/output/checkpoint-13500/config.json
# Model weights saved in /content/output/checkpoint-13500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-13500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-13500/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-14000
# Configuration saved in /content/output/checkpoint-14000/config.json
# Model weights saved in /content/output/checkpoint-14000/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-14000/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-14000/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-14500
# Configuration saved in /content/output/checkpoint-14500/config.json
# Model weights saved in /content/output/checkpoint-14500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-14500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-14500/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-15000
# Configuration saved in /content/output/checkpoint-15000/config.json
# Model weights saved in /content/output/checkpoint-15000/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-15000/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-15000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 3800
#   Batch size = 16
# Saving model checkpoint to /content/output/checkpoint-15500
# Configuration saved in /content/output/checkpoint-15500/config.json
# Model weights saved in /content/output/checkpoint-15500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-15500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-15500/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-16000
# Configuration saved in /content/output/checkpoint-16000/config.json
# Model weights saved in /content/output/checkpoint-16000/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-16000/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-16000/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-16500
# Configuration saved in /content/output/checkpoint-16500/config.json
# Model weights saved in /content/output/checkpoint-16500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-16500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-16500/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-17000
# Configuration saved in /content/output/checkpoint-17000/config.json
# Model weights saved in /content/output/checkpoint-17000/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-17000/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-17000/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-17500
# Configuration saved in /content/output/checkpoint-17500/config.json
# Model weights saved in /content/output/checkpoint-17500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-17500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-17500/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-18000
# Configuration saved in /content/output/checkpoint-18000/config.json
# Model weights saved in /content/output/checkpoint-18000/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-18000/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-18000/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-18500
# Configuration saved in /content/output/checkpoint-18500/config.json
# Model weights saved in /content/output/checkpoint-18500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-18500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-18500/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-19000
# Configuration saved in /content/output/checkpoint-19000/config.json
# Model weights saved in /content/output/checkpoint-19000/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-19000/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-19000/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-19500
# Configuration saved in /content/output/checkpoint-19500/config.json
# Model weights saved in /content/output/checkpoint-19500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-19500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-19500/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-20000
# Configuration saved in /content/output/checkpoint-20000/config.json
# Model weights saved in /content/output/checkpoint-20000/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-20000/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-20000/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-20500
# Configuration saved in /content/output/checkpoint-20500/config.json
# Model weights saved in /content/output/checkpoint-20500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-20500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-20500/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-21000
# Configuration saved in /content/output/checkpoint-21000/config.json
# Model weights saved in /content/output/checkpoint-21000/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-21000/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-21000/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-21500
# Configuration saved in /content/output/checkpoint-21500/config.json
# Model weights saved in /content/output/checkpoint-21500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-21500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-21500/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-22000
# Configuration saved in /content/output/checkpoint-22000/config.json
# Model weights saved in /content/output/checkpoint-22000/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-22000/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-22000/special_tokens_map.json
# Saving model checkpoint to /content/output/checkpoint-22500
# Configuration saved in /content/output/checkpoint-22500/config.json
# Model weights saved in /content/output/checkpoint-22500/pytorch_model.bin
# tokenizer config file saved in /content/output/checkpoint-22500/tokenizer_config.json
# Special tokens file saved in /content/output/checkpoint-22500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 3800
#   Batch size = 16
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Saving model checkpoint to out
# Configuration saved in out/config.json
# Model weights saved in out/pytorch_model.bin
# tokenizer config file saved in out/tokenizer_config.json
# Special tokens file saved in out/special_tokens_map.json
# ***** train metrics *****
#   epoch                    =        3.0
#   total_flos               =  9738483GF
#   train_loss               =     0.1949
#   train_runtime            = 0:57:35.02
#   train_samples_per_second =    104.196
#   train_steps_per_second   =      6.512

# %%
predict_results = trainer.predict(test_ds, metric_key_prefix="predict", max_length=256)
metrics = predict_results.metrics

trainer.log_metrics("predict", metrics)
trainer.save_metrics("predict", metrics)
# Out:
# ***** Running Prediction *****
#   Num examples = 3800
#   Batch size = 16
# ***** predict metrics *****
#   predict_bleu               =     99.089
#   predict_gen_len            =    58.6937
#   predict_loss               =     0.0045
#   predict_runtime            = 0:04:24.74
#   predict_samples_per_second =     14.353
#   predict_steps_per_second   =      0.899

# %%
predictions = tokenizer.batch_decode(
	predict_results.predictions, skip_special_tokens=True, clean_up_tokenization_spaces=True
)
predictions = [pred.strip() for pred in predictions]
print(predictions[:10])
with open('generated.txt', "w") as writer:
	writer.write("\n".join(predictions))
# Out:
# ['FleetCenter. the at concert rap the for time in Sunday on Back family. the on Check Saturday. on Out ride. elevator an trade, the in say they as was, camp training of start the since California to trip round third His yesterday. practice at back was Payton Gary traveling this with OK Celtics', 'Israel. by poisoned was he that public Palestinian the among rumours increasing amid death Arafats Yasser into inquiry of commission official an up set to is Authority Palestinian THE Arafat poisoned Israel that rumours investigate Palestinians', 'said. police Thailand, western in Kwai River the over Bridge famous the near gunmen unknown by dead shot were Britons Two - AFP (AFP) bridge railway death near dead shot Britons Two', 'holding #39;re you that suggesting you quot;Are whoa!... when Turin in Games Winter Olympic 2006 the in playing possibly Lemieux Mario about talking himself found Gretzky Wayne question in still Olympics in Pros', 'Saturday. on League Premier Scottish the in Dundee against win 3-0 their in Celtic champions for goals two first his scored Camara Henri striker Senegal win 3-0 in Celtic for goals first scores Camara #39;s Senegal', 'warning. a with off let be to him expect campaigners anti-racism but - Aragones Luis coach national against file disciplinary a opened yesterday federation football Spanish THE inquiry racism faces coach Spain', 'yesterday. said reports media year, next for races One Formula of calendar provisional the from dropped been has Prix Grand British The axed gets Prix Grand British', 'showed. report government a September, in showrooms car and malls in splurged and prices energy rising off shrugged -- economy US the in dynamo the -- Shoppers - (AFP) WASHINGTON September in splurge shoppers American', "lawful? it is but house, the within content digital share effortlessly you lets product latest Belkin's Streaming Media Slick Offers RemoteTV Look: First", '... died civilians three say authorities Ossetian while fighting, earlier in killed were soldiers its of three says Georgia peacekeepers. to over area the turning Thursday, Tskhinvali of capital of Ossetian the above heights the from withdrew soldiers The Ossetia South Leave Troops Georgian']
